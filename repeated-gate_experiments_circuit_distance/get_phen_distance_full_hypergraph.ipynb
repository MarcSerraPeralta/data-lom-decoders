# %%
import time
import stim

from surface_sim import Layout
from surface_sim.setup import CircuitNoiseSetup
from surface_sim.models import PhenomenologicalDepolNoiseModel
from surface_sim import Detectors
from surface_sim.experiments import schedule_from_circuit, experiment_from_schedule
from surface_sim.circuit_blocks.unrot_surface_code_css import gate_to_iterator
from surface_sim.layouts import unrot_surface_codes
import surface_sim.experiments.unrot_surface_code_css as exp
from qec_util.distance import get_circuit_distance


# INPUTS
EXPERIMENTS = ["I", "S", "H", "CNOT-alternating", "CNOT-no-alternating"]
DISTANCES = [3, 5]
NOISE_MODEL = PhenomenologicalDepolNoiseModel
BASES = ["Z", "X"]
FRAMES = ["pre-gate", "post-gate"]

# %%
# GENERATE CIRCUIT
def get_num_qubits(experiment):
    return 1 if experiment in ["I", "S", "H", "SQRT_X"] else 2

def get_circuit(experiment, distance, basis):
    num_qubits = get_num_qubits(experiment)

    # reset
    circuit_str = ""
    if basis == "X":
        circuit_str = "RX " + " ".join([f"{i}" for i in range(num_qubits)]) + "\nTICK\n"
    else:
        circuit_str = "R " + " ".join([f"{i}" for i in range(num_qubits)]) + "\nTICK\n"

    # clifford gates + QEC cycles
    if num_qubits == 1:
        circuit_str += f"{experiment} 0\nTICK\n"*(distance+1)
    elif experiment == "CNOT-no-alternating":
        circuit_str += "CNOT 0 1\nTICK\n"*(distance+1)
    elif experiment == "CNOT-alternating":
        circuit_str += "CNOT 0 1\nTICK\nCNOT 1 0\nTICK\n"*((distance+1)//2)
    elif experiment == "CZ":
        circuit_str += "CZ 0 1\nTICK\n"*(distance+1)
    else:
        raise ValueError(f"{experiment} is not known.")

    # measurment
    if basis == "X":
        circuit_str += "MX " + " ".join([f"{i}" for i in range(num_qubits)])
    else:
        circuit_str += "M " + " ".join([f"{i}" for i in range(num_qubits)])

    circuit = stim.Circuit(circuit_str)

    return circuit

# %%
for experiment_name in EXPERIMENTS:
    for basis in BASES:
        for frame in FRAMES:
            for distance in DISTANCES:
                layouts = unrot_surface_codes(get_num_qubits(experiment_name), distance=distance)
                qubit_inds = {}
                anc_coords = {}
                anc_qubits = []
                stab_coords = {}
                for l, layout in enumerate(layouts):
                    qubit_inds.update(layout.qubit_inds())
                    anc_qubits += layout.get_qubits(role="anc")
                    coords = layout.anc_coords()
                    anc_coords.update(coords)
                    stab_coords[f"Z{l}"] = [v for k,v in coords.items() if k[0] == "Z"]
                    stab_coords[f"X{l}"] = [v for k,v in coords.items() if k[0] == "X"]

                circuit = get_circuit(experiment_name, distance, basis)

                setup = CircuitNoiseSetup()
                setup.set_var_param("prob", 1e-3)
                model = NOISE_MODEL(setup=setup, qubit_inds=qubit_inds)
                detectors = Detectors(anc_qubits, frame=frame, anc_coords=anc_coords)

                schedule = schedule_from_circuit(circuit, layouts, gate_to_iterator)
                experiment = experiment_from_schedule(
                    schedule, model, detectors, anc_reset=True, anc_detectors=None
                )
                print("start=", time.strftime("%D %H:%M:%S"))
                d_circ = get_circuit_distance(experiment)
                print(f"{experiment_name} b={basis} f={frame} d={distance} d_circ={d_circ}")
                print("finish=", time.strftime("%D %H:%M:%S"))
# Out:
# start= 02/13/25 16:20:52
# I b=Z f=pre-gate d=3 d_circ=3
# finish= 02/13/25 16:20:52
# start= 02/13/25 16:20:53
# I b=Z f=pre-gate d=5 d_circ=5
# finish= 02/13/25 16:20:53
# start= 02/13/25 16:20:54
# I b=Z f=post-gate d=3 d_circ=3
# finish= 02/13/25 16:20:54
# start= 02/13/25 16:20:55
# I b=Z f=post-gate d=5 d_circ=5
# finish= 02/13/25 16:20:56
# start= 02/13/25 16:20:56
# I b=X f=pre-gate d=3 d_circ=3
# finish= 02/13/25 16:20:56
# start= 02/13/25 16:20:57
# I b=X f=pre-gate d=5 d_circ=5
# finish= 02/13/25 16:20:59
# start= 02/13/25 16:20:59
# I b=X f=post-gate d=3 d_circ=3
# finish= 02/13/25 16:20:59
# start= 02/13/25 16:21:00
# I b=X f=post-gate d=5 d_circ=5
# finish= 02/13/25 16:21:02
# start= 02/13/25 16:21:02
# S b=Z f=pre-gate d=3 d_circ=3
# finish= 02/13/25 16:21:02
# start= 02/13/25 16:21:03
# S b=Z f=pre-gate d=5 d_circ=5
# finish= 02/13/25 16:21:06
# start= 02/13/25 16:21:06
# S b=Z f=post-gate d=3 d_circ=3
# finish= 02/13/25 16:21:06
# start= 02/13/25 16:21:08
# S b=Z f=post-gate d=5 d_circ=5
# finish= 02/13/25 16:21:11
# start= 02/13/25 16:21:11
# S b=X f=pre-gate d=3 d_circ=3
# finish= 02/13/25 16:21:11
# start= 02/13/25 16:21:13
# S b=X f=pre-gate d=5 d_circ=5
# finish= 02/13/25 16:21:19
# start= 02/13/25 16:21:19
# S b=X f=post-gate d=3 d_circ=3
# finish= 02/13/25 16:21:19
# start= 02/13/25 16:21:20
# S b=X f=post-gate d=5 d_circ=5
# finish= 02/13/25 16:21:30
# start= 02/13/25 16:21:30
# H b=Z f=pre-gate d=3 d_circ=3
# finish= 02/13/25 16:21:30
# start= 02/13/25 16:21:31
# H b=Z f=pre-gate d=5 d_circ=5
# finish= 02/13/25 16:21:32
# start= 02/13/25 16:21:33
# H b=Z f=post-gate d=3 d_circ=3
# finish= 02/13/25 16:21:33
# start= 02/13/25 16:21:34
# H b=Z f=post-gate d=5 d_circ=5
# finish= 02/13/25 16:21:35
# start= 02/13/25 16:21:35
# H b=X f=pre-gate d=3 d_circ=3
# finish= 02/13/25 16:21:35
# start= 02/13/25 16:21:36
# H b=X f=pre-gate d=5 d_circ=5
# finish= 02/13/25 16:21:37
# start= 02/13/25 16:21:37
# H b=X f=post-gate d=3 d_circ=3
# finish= 02/13/25 16:21:38
# start= 02/13/25 16:21:39
# H b=X f=post-gate d=5 d_circ=5
# finish= 02/13/25 16:21:40
# start= 02/13/25 16:21:40
# CNOT-alternating b=Z f=pre-gate d=3 d_circ=3
# finish= 02/13/25 16:21:40
# start= 02/13/25 16:21:43
# CNOT-alternating b=Z f=pre-gate d=5 d_circ=5
# finish= 02/13/25 16:22:07
# start= 02/13/25 16:22:08
# CNOT-alternating b=Z f=post-gate d=3 d_circ=3
# finish= 02/13/25 16:22:08
# start= 02/13/25 16:22:11
# CNOT-alternating b=Z f=post-gate d=5 d_circ=5
# finish= 02/13/25 16:22:38
# start= 02/13/25 16:22:39
# CNOT-alternating b=X f=pre-gate d=3 d_circ=3
# finish= 02/13/25 16:22:39
# start= 02/13/25 16:22:42
# CNOT-alternating b=X f=pre-gate d=5 d_circ=5
# finish= 02/13/25 16:23:17
# start= 02/13/25 16:23:17
# CNOT-alternating b=X f=post-gate d=3 d_circ=3
# finish= 02/13/25 16:23:17
# start= 02/13/25 16:23:21
# CNOT-alternating b=X f=post-gate d=5 d_circ=5
# finish= 02/13/25 16:23:45
# start= 02/13/25 16:23:46
# CNOT-no-alternating b=Z f=pre-gate d=3 d_circ=3
# finish= 02/13/25 16:23:46
# start= 02/13/25 16:23:49
# CNOT-no-alternating b=Z f=pre-gate d=5 d_circ=5
# finish= 02/13/25 16:24:24
# start= 02/13/25 16:24:25
# CNOT-no-alternating b=Z f=post-gate d=3 d_circ=3
# finish= 02/13/25 16:24:25
# start= 02/13/25 16:24:28
# CNOT-no-alternating b=Z f=post-gate d=5 d_circ=5
# finish= 02/13/25 16:25:26
# start= 02/13/25 16:25:27
# CNOT-no-alternating b=X f=pre-gate d=3 d_circ=3
# finish= 02/13/25 16:25:27
# start= 02/13/25 16:25:30
# CNOT-no-alternating b=X f=pre-gate d=5 d_circ=5
# finish= 02/13/25 16:25:50
# start= 02/13/25 16:25:51
# CNOT-no-alternating b=X f=post-gate d=3 d_circ=3
# finish= 02/13/25 16:25:51
# start= 02/13/25 16:25:54
# CNOT-no-alternating b=X f=post-gate d=5 d_circ=5
# finish= 02/13/25 16:26:16

# %%
# INPUTS
EXPERIMENTS = ["S", "H"]
DISTANCES = [7]
NOISE_MODEL = PhenomenologicalDepolNoiseModel
BASES = ["Z", "X"]
FRAMES = ["pre-gate", "post-gate"]

for experiment_name in EXPERIMENTS:
    for basis in BASES:
        for frame in FRAMES:
            for distance in DISTANCES:
                layouts = unrot_surface_codes(get_num_qubits(experiment_name), distance=distance)
                qubit_inds = {}
                anc_coords = {}
                anc_qubits = []
                stab_coords = {}
                for l, layout in enumerate(layouts):
                    qubit_inds.update(layout.qubit_inds())
                    anc_qubits += layout.get_qubits(role="anc")
                    coords = layout.anc_coords()
                    anc_coords.update(coords)
                    stab_coords[f"Z{l}"] = [v for k,v in coords.items() if k[0] == "Z"]
                    stab_coords[f"X{l}"] = [v for k,v in coords.items() if k[0] == "X"]

                circuit = get_circuit(experiment_name, distance, basis)

                setup = CircuitNoiseSetup()
                setup.set_var_param("prob", 1e-3)
                model = NOISE_MODEL(setup=setup, qubit_inds=qubit_inds)
                detectors = Detectors(anc_qubits, frame=frame, anc_coords=anc_coords)

                schedule = schedule_from_circuit(circuit, layouts, gate_to_iterator)
                experiment = experiment_from_schedule(
                    schedule, model, detectors, anc_reset=True, anc_detectors=None
                )
                print("start=", time.strftime("%D %H:%M:%S"))
                d_circ = get_circuit_distance(experiment)
                print(f"{experiment_name} b={basis} f={frame} d={distance} d_circ={d_circ}")
                print("finish=", time.strftime("%D %H:%M:%S"))
# Out:
# start= 02/13/25 16:26:19
# S b=Z f=pre-gate d=7 d_circ=7
# finish= 02/13/25 17:04:45
# start= 02/13/25 17:04:49
# S b=Z f=post-gate d=7 d_circ=7
# finish= 02/13/25 17:51:07
# start= 02/13/25 17:51:11
# S b=X f=pre-gate d=7 d_circ=7
# finish= 02/14/25 00:48:24
# start= 02/14/25 00:48:28
# S b=X f=post-gate d=7 d_circ=7
# finish= 02/14/25 06:17:40
# start= 02/14/25 06:17:44
# H b=Z f=pre-gate d=7 d_circ=7
# finish= 02/14/25 06:22:34
# start= 02/14/25 06:22:38
# H b=Z f=post-gate d=7 d_circ=7
# finish= 02/14/25 06:25:46
# start= 02/14/25 06:25:49
# H b=X f=pre-gate d=7 d_circ=7
# finish= 02/14/25 06:28:37
# start= 02/14/25 06:28:41
# H b=X f=post-gate d=7 d_circ=7
# finish= 02/14/25 06:33:21
